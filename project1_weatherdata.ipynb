# %%
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import requests

# %%
# Make a reference to the books.csv file path

csv_path_all="city_weather_averages.csv"

# %%
city_df=pd.read_csv(csv_path_all, encoding="utf-8")
city_df
# Out:
#       Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 0   Dallas    Jan                 79.1                 30.8         52.0
# 1   Dallas    Feb                 80.1                 28.1         51.1
# 2   Dallas    Mar                 88.1                 42.2         64.4
# 3   Dallas    Apr                 96.2                 41.0         65.9
# 4   Dallas    May                 95.0                 55.1         75.2
# ..     ...    ...                  ...                  ...          ...
# 91   Miami    May                 87.7                 66.5         78.9
# 92   Miami    Jun                 90.2                 74.7         83.4
# 93   Miami    Jul                 96.2                 74.9         84.6
# 94   Miami    Aug                 92.0                 75.2         85.2
# 95   Miami    Sep                 91.1                 75.1         83.6
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
det_df=city_df.loc[city_df["Name"] == "Detroit", :]
det_df
# Out:
#        Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 68  Detroit    Jan                 54.6                 14.8         32.4
# 69  Detroit    Feb                 52.5                  4.4         29.9
# 70  Detroit    Mar                 63.6                 20.6         40.5
# 71  Detroit    Apr                 70.0                 25.8         44.9
# 72  Detroit    May                 88.8                 30.1         57.3
# 73  Detroit    Jun                 91.5                 47.6         71.4
# 74  Detroit    Jul                 93.5                 62.8         77.4
# 75  Detroit    Aug                 92.3                 57.4         73.2
# 76  Detroit    Sep                 83.7                 39.1         63.7
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 68         3.8         NaN           3.40         NaN        23.6       40.3
# ...

# %%
miami_df=city_df.loc[city_df["Name"] == "Miami", :]
miami_df
# Out:
#      Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 87  Miami    Jan                 87.2                 41.9         71.4
# 88  Miami    Feb                 83.0                 52.5         72.5
# 89  Miami    Mar                 85.2                 56.7         75.7
# 90  Miami    Apr                 91.5                 68.7         80.1
# 91  Miami    May                 87.7                 66.5         78.9
# 92  Miami    Jun                 90.2                 74.7         83.4
# 93  Miami    Jul                 96.2                 74.9         84.6
# 94  Miami    Aug                 92.0                 75.2         85.2
# 95  Miami    Sep                 91.1                 75.1         83.6
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 87        34.8        89.5           1.89         NaN        26.9       34.2
# 88         NaN        86.7           3.04         NaN        20.8       32.2
# ...

# %%
dallas_df=city_df.loc[city_df["Name"] == "Dallas", :]
dallas_df
# Out:
#      Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 0  Dallas    Jan                 79.1                 30.8         52.0
# 1  Dallas    Feb                 80.1                 28.1         51.1
# 2  Dallas    Mar                 88.1                 42.2         64.4
# 3  Dallas    Apr                 96.2                 41.0         65.9
# 4  Dallas    May                 95.0                 55.1         75.2
# 5  Dallas    Jun                 99.0                 65.0         83.7
# 6  Dallas    Jul                101.9                 74.0         86.4
# 7  Dallas    Aug                105.2                 72.0         87.6
# 8  Dallas    Sep                 93.8                 56.9         76.9
# 9  Dallas    Dec                 45.0                 45.0         45.0
#
#    Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 0        17.9         NaN           6.28         NaN        27.7       36.8
# ...

# %%
boston_df=city_df.loc[city_df["Name"] == "Boston", :]
boston_df
# Out:
#       Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 59  Boston    Jan                 70.6                 13.5         37.1
# 60  Boston    Feb                 61.4                 11.5         36.8
# 61  Boston    Mar                 72.5                 21.1         42.8
# 62  Boston    Apr                 62.1                 33.3         45.9
# 63  Boston    May                 83.8                 37.4         58.0
# 64  Boston    Jun                 90.0                 50.3         69.5
# 65  Boston    Jul                 95.2                 60.2         75.5
# 66  Boston    Aug                 92.5                 59.1         74.4
# 67  Boston    Sep                 85.6                 45.0         65.4
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 59        10.2         NaN           1.39         NaN        34.4       46.0
# 60         1.4         NaN           3.29         NaN        17.2       52.9
# ...

# %%
honolulu_df=city_df.loc[city_df["Name"] == "Honolulu", :]
honolulu_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 20  Honolulu    Jan                 81.6                 65.3         75.0
# 21  Honolulu    Feb                 83.4                 62.4         73.4
# 22  Honolulu    Mar                 81.5                 65.9         73.6
# 23  Honolulu    Apr                 83.4                 66.8         75.7
# 24  Honolulu    May                 85.5                 70.5         77.2
# 25  Honolulu    Jun                 87.7                 73.2         79.1
# 26  Honolulu    Jul                 89.0                 73.1         79.8
# 27  Honolulu    Aug                 89.9                 73.8         80.6
# 28  Honolulu    Sep                 89.1                 70.1         80.4
# 29  Honolulu    Dec                 76.2                 75.4         75.8
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
denver_df=city_df.loc[city_df["Name"] == "Denver", :]
denver_df
# Out:
#       Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 10  Denver    Jan                 60.2                 10.3         34.9
# 11  Denver    Feb                 71.5                  1.8         29.7
# 12  Denver    Mar                 67.9                 17.9         42.3
# 13  Denver    Apr                 80.1                 13.3         46.9
# 14  Denver    May                 90.2                 33.8         59.2
# 15  Denver    Jun                 94.7                 41.0         70.5
# 16  Denver    Jul                 96.5                 54.7         74.5
# 17  Denver    Aug                 97.4                 42.8         75.7
# 18  Denver    Sep                 98.1                 29.9         64.8
# 19  Denver    Dec                 33.9                 31.7         32.8
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 10         0.4         NaN           0.07        1.18        28.0       43.8
# ...

# %%
la_df=city_df.loc[city_df["Name"] == "LA", :]
la_df
# Out:
#    Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 77   LA    Jan                 83.0                 46.1         59.9
# 78   LA    Feb                 88.1                 42.2         61.8
# 79   LA    Mar                 80.1                 47.0         60.6
# 80   LA    Apr                 92.9                 51.2         65.5
# 81   LA    May                 93.8                 57.8         69.4
# 82   LA    Jun                 98.1                 61.1         70.1
# 83   LA    Jul                 90.0                 60.2         70.6
# 84   LA    Aug                 98.1                 60.2         74.7
# 85   LA    Sep                109.1                 62.1         74.1
# 86   LA    Dec                 57.8                 57.8         57.8
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 77        49.4        80.5           0.31         NaN         9.2       36.7
# ...

# %%
sf_df=city_df.loc[city_df["Name"] == "San Fran", :]
sf_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 39  San Fran    Jan                 63.6                 44.6         52.0
# 40  San Fran    Feb                 70.1                 44.1         54.3
# 41  San Fran    Mar                 68.7                 42.8         53.1
# 42  San Fran    Apr                 72.8                 46.9         55.5
# 43  San Fran    May                 83.8                 51.0         59.1
# 44  San Fran    Jun                 75.4                 53.8         60.0
# 45  San Fran    Jul                 70.0                 52.1         58.9
# 46  San Fran    Aug                 82.7                 54.1         61.3
# 47  San Fran    Sep                 94.5                 55.2         62.9
# 48  San Fran    Dec                 53.5                 52.7         53.0
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
nyc_df=city_df.loc[city_df["Name"] == "NYC", :]
nyc_df
# Out:
#    Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 30  NYC    Jan                 65.6                 22.2         39.9
# 31  NYC    Feb                 58.1                 17.9         40.2
# 32  NYC    Mar                 72.0                 26.5         47.4
# 33  NYC    Apr                 67.8                 37.6         50.3
# 34  NYC    May                 82.1                 36.2         59.9
# 35  NYC    Jun                 87.5                 53.0         73.0
# 36  NYC    Jul                 93.2                 67.4         80.0
# 37  NYC    Aug                 91.1                 66.0         77.9
# 38  NYC    Sep                 87.9                 52.9         70.7
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 30        15.8         NaN           0.54         NaN        16.1       58.7
# 31        10.1         NaN           1.09         NaN        20.1       53.4
# ...

# %%
seattle_df=city_df.loc[city_df["Name"] == "Seattle", :]
seattle_df
# Out:
#        Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 49  Seattle    Jan                 57.8                 29.0         44.9
# 50  Seattle    Feb                 57.8                 30.8         43.6
# 51  Seattle    Mar                 61.1                 29.9         44.5
# 52  Seattle    Apr                 69.2                 34.1         52.1
# 53  Seattle    May                 87.2                 42.2         59.0
# 54  Seattle    Jun                 81.0                 51.2         61.7
# 55  Seattle    Jul                 92.9                 55.1         66.8
# 56  Seattle    Aug                 97.1                 52.1         67.8
# 57  Seattle    Sep                 90.0                 51.2         66.3
# 58  Seattle    Dec                 55.1                 54.0         54.3
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
jan_df = city_df.loc[city_df["Period"] == "Jan", :]
jan_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 0     Dallas    Jan                 79.1                 30.8         52.0
# 10    Denver    Jan                 60.2                 10.3         34.9
# 20  Honolulu    Jan                 81.6                 65.3         75.0
# 30       NYC    Jan                 65.6                 22.2         39.9
# 39  San Fran    Jan                 63.6                 44.6         52.0
# 49   Seattle    Jan                 57.8                 29.0         44.9
# 59    Boston    Jan                 70.6                 13.5         37.1
# 68   Detroit    Jan                 54.6                 14.8         32.4
# 77        LA    Jan                 83.0                 46.1         59.9
# 87     Miami    Jan                 87.2                 41.9         71.4
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
feb_df = city_df.loc[city_df["Period"] == "Feb", :]
feb_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 1     Dallas    Feb                 80.1                 28.1         51.1
# 11    Denver    Feb                 71.5                  1.8         29.7
# 21  Honolulu    Feb                 83.4                 62.4         73.4
# 31       NYC    Feb                 58.1                 17.9         40.2
# 40  San Fran    Feb                 70.1                 44.1         54.3
# 50   Seattle    Feb                 57.8                 30.8         43.6
# 60    Boston    Feb                 61.4                 11.5         36.8
# 69   Detroit    Feb                 52.5                  4.4         29.9
# 78        LA    Feb                 88.1                 42.2         61.8
# 88     Miami    Feb                 83.0                 52.5         72.5
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
mar_df = city_df.loc[city_df["Period"] == "Mar", :]
mar_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 2     Dallas    Mar                 88.1                 42.2         64.4
# 12    Denver    Mar                 67.9                 17.9         42.3
# 22  Honolulu    Mar                 81.5                 65.9         73.6
# 32       NYC    Mar                 72.0                 26.5         47.4
# 41  San Fran    Mar                 68.7                 42.8         53.1
# 51   Seattle    Mar                 61.1                 29.9         44.5
# 61    Boston    Mar                 72.5                 21.1         42.8
# 70   Detroit    Mar                 63.6                 20.6         40.5
# 79        LA    Mar                 80.1                 47.0         60.6
# 89     Miami    Mar                 85.2                 56.7         75.7
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
apr_df = city_df.loc[city_df["Period"] == "Apr", :]
apr_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 3     Dallas    Apr                 96.2                 41.0         65.9
# 13    Denver    Apr                 80.1                 13.3         46.9
# 23  Honolulu    Apr                 83.4                 66.8         75.7
# 33       NYC    Apr                 67.8                 37.6         50.3
# 42  San Fran    Apr                 72.8                 46.9         55.5
# 52   Seattle    Apr                 69.2                 34.1         52.1
# 62    Boston    Apr                 62.1                 33.3         45.9
# 71   Detroit    Apr                 70.0                 25.8         44.9
# 80        LA    Apr                 92.9                 51.2         65.5
# 90     Miami    Apr                 91.5                 68.7         80.1
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
may_df = city_df.loc[city_df["Period"] == "May", :]
may_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 4     Dallas    May                 95.0                 55.1         75.2
# 14    Denver    May                 90.2                 33.8         59.2
# 24  Honolulu    May                 85.5                 70.5         77.2
# 34       NYC    May                 82.1                 36.2         59.9
# 43  San Fran    May                 83.8                 51.0         59.1
# 53   Seattle    May                 87.2                 42.2         59.0
# 63    Boston    May                 83.8                 37.4         58.0
# 72   Detroit    May                 88.8                 30.1         57.3
# 81        LA    May                 93.8                 57.8         69.4
# 91     Miami    May                 87.7                 66.5         78.9
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
jun_df = city_df.loc[city_df["Period"] == "Jun", :]
jun_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 5     Dallas    Jun                 99.0                 65.0         83.7
# 15    Denver    Jun                 94.7                 41.0         70.5
# 25  Honolulu    Jun                 87.7                 73.2         79.1
# 35       NYC    Jun                 87.5                 53.0         73.0
# 44  San Fran    Jun                 75.4                 53.8         60.0
# 54   Seattle    Jun                 81.0                 51.2         61.7
# 64    Boston    Jun                 90.0                 50.3         69.5
# 73   Detroit    Jun                 91.5                 47.6         71.4
# 82        LA    Jun                 98.1                 61.1         70.1
# 92     Miami    Jun                 90.2                 74.7         83.4
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
jul_df = city_df.loc[city_df["Period"] == "Jul", :]
jul_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 6     Dallas    Jul                101.9                 74.0         86.4
# 16    Denver    Jul                 96.5                 54.7         74.5
# 26  Honolulu    Jul                 89.0                 73.1         79.8
# 36       NYC    Jul                 93.2                 67.4         80.0
# 45  San Fran    Jul                 70.0                 52.1         58.9
# 55   Seattle    Jul                 92.9                 55.1         66.8
# 65    Boston    Jul                 95.2                 60.2         75.5
# 74   Detroit    Jul                 93.5                 62.8         77.4
# 83        LA    Jul                 90.0                 60.2         70.6
# 93     Miami    Jul                 96.2                 74.9         84.6
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
aug_df = city_df.loc[city_df["Period"] == "Aug", :]
aug_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 7     Dallas    Aug                105.2                 72.0         87.6
# 17    Denver    Aug                 97.4                 42.8         75.7
# 27  Honolulu    Aug                 89.9                 73.8         80.6
# 37       NYC    Aug                 91.1                 66.0         77.9
# 46  San Fran    Aug                 82.7                 54.1         61.3
# 56   Seattle    Aug                 97.1                 52.1         67.8
# 66    Boston    Aug                 92.5                 59.1         74.4
# 75   Detroit    Aug                 92.3                 57.4         73.2
# 84        LA    Aug                 98.1                 60.2         74.7
# 94     Miami    Aug                 92.0                 75.2         85.2
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
# Filter the data so that only temps in Jan are in a DataFrame
sep_df = city_df.loc[city_df["Period"] == "Sep", :]
sep_df
# Out:
#         Name Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 8     Dallas    Sep                 93.8                 56.9         76.9
# 18    Denver    Sep                 98.1                 29.9         64.8
# 28  Honolulu    Sep                 89.1                 70.1         80.4
# 38       NYC    Sep                 87.9                 52.9         70.7
# 47  San Fran    Sep                 94.5                 55.2         62.9
# 57   Seattle    Sep                 90.0                 51.2         66.3
# 67    Boston    Sep                 85.6                 45.0         65.4
# 76   Detroit    Sep                 83.7                 39.1         63.7
# 85        LA    Sep                109.1                 62.1         74.1
# 95     Miami    Sep                 91.1                 75.1         83.6
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# ...

# %%
#find city averages

seattle_average=seattle_df["Temperature"].mean()
denver_average=denver_df["Temperature"].mean()
nyc_average=nyc_df["Temperature"].mean()
la_average=la_df["Temperature"].mean()
sf_average=sf_df["Temperature"].mean()
dallas_average=dallas_df["Temperature"].mean()
honolulu_average=honolulu_df["Temperature"].mean()
miami_average=miami_df["Temperature"].mean()
boston_average=boston_df["Temperature"].mean()
det_average=det_df["Temperature"].mean()

# %%
averages=[seattle_average, denver_average, nyc_average, la_average, sf_average, dallas_average, honolulu_average, miami_average, boston_average, det_average]


average_df=pd.DataFrame(averages)
round(average_df,2)
# Out:
#        0
# 0  56.10
# 1  53.13
# 2  59.92
# 3  66.45
# 4  57.01
# 5  68.82
# 6  77.06
# 7  79.49
# 8  56.16
# 9  54.52

# %%
det_df["Temperature"].describe()
# Out:
# count     9.000000
# mean     54.522222
# std      18.144956
# min      29.900000
# 25%      40.500000
# 50%      57.300000
# 75%      71.400000
# max      77.400000
# Name: Temperature, dtype: float64

# %%
plot.
